# %%
import transformers

print(transformers.__version__)
# Out:
# 4.15.0

# %% [markdown]
# # Train a language model

# %% [markdown]
# ## Preparing the dataset

# %%
def splitTolenWords(text, nwords):
    words = text.split(" ")
    count = int(len(words)/nwords)
    sentences = [" ".join(words[(i*nwords):((i+1)*nwords)]) for i in range(count)]
    return(sentences)

# %%
with open("data_splits/trumpGeneratorText.txt", encoding = "utf-8") as f:
    trump = f.read()

# %%
sentences = splitTolenWords(trump, 100)

# %%
from datasets import Dataset
dataset = Dataset.from_dict({"train": sentences})

# %%
dataset = dataset.train_test_split(test_size=0.1)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['train'],
#         num_rows: 2829
#     })
#     test: Dataset({
#         features: ['train'],
#         num_rows: 315
#     })
# })

# %% [markdown]
# ## Causal Language modeling

# %% [markdown]
# For causal language modeling (CLM) we are going to take all the texts in our dataset and concatenate them after they are tokenized. Then we will split them in examples of a certain sequence length. This way the model will receive chunks of contiguous text that may look like:
# ```
# part of text 1
# ```
# or
# ```
# end of text 1 [BOS_TOKEN] beginning of text 2
# ```
# depending on whether they span over several of the original texts in the dataset or not. The labels will be the same as the inputs, shifted to the left.
#
# We will use the [`gpt2`](https://huggingface.co/gpt2) architecture for this example. You can pick any of the checkpoints listed [here](https://huggingface.co/models?filter=causal-lm) instead. For the tokenizer, you can replace the checkpoint by the one you trained yourself.

# %%
model_checkpoint = "gpt2"
tokenizer_checkpoint = 'gpt2'

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(tokenizer_checkpoint)

def tokenize_function(examples):
    return tokenizer(examples["train"])

tokenized_datasets = dataset.map(
    tokenize_function, batched=True, num_proc=1, remove_columns=["train"]
)
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
#block_size = tokenizer.model_max_length
block_size = 200

def group_texts(examples):
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the small remainder, we could add padding if the model supported it instead of this drop, you can
    # customize this part to your needs.
    total_length = (total_length // block_size) * block_size
    # Split by chunks of max_len.
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    result["labels"] = result["input_ids"].copy()
    return result

lm_datasets = tokenized_datasets.map(
    group_texts,
    batched=True,
    batch_size=1000,
    num_proc=1,
)
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenizer.decode(lm_datasets["train"][3]["input_ids"])
# Out:
# " everything we had, it was depleted.  Now we've rebuilt our military like never before.  And all But if you want to vote for a weak candidate tomorrow, go ahead.  Pick one.  Pick the weakest one you think, I don't know who it is.  We are a big party with big ideas for the future.  Very big.  We become a big party and an open-minded party and we're the party that people like.  We're the hot party and we're the party with all the enthusiasm.  We are fighting for school choice because no parent should ever be forced to send their child to a failing government school.  Right?word.  That's the word.  I stand before you today to declare the silent majority is stronger than ever before.  Five months from now, we're going to defeat sleepy Joe Biden.  Boy, does he get a pass from these people, huh? We're going to stop the radical left"

# %% [markdown]
# Now that the data has been cleaned, we're ready to instantiate our `Model`. First we create the model using the same config as our checkpoint, but initialized with random weights:

# %%
batch_size = 1
num_epochs = 100

# %%
from transformers import DefaultDataCollator

data_collator = DefaultDataCollator(return_tensors='tf')

train_set = lm_datasets["train"].to_tf_dataset(
    columns=["attention_mask", "input_ids", "labels"],
    shuffle=True,
    batch_size=batch_size,
    collate_fn=data_collator
)
validation_set = lm_datasets["test"].to_tf_dataset(
    columns=["attention_mask", "input_ids", "labels"],
    shuffle=False,
    batch_size=batch_size,
    collate_fn=data_collator
)

# %%
from transformers import create_optimizer
import tensorflow as tf

batches_per_epoch = len(lm_datasets["train"]) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(
    init_lr=0.00001, 
    num_warmup_steps=0, 
    num_train_steps=total_train_steps
)

from transformers import AutoConfig, TFAutoModelForCausalLM

config = AutoConfig.from_pretrained(model_checkpoint)
model = TFAutoModelForCausalLM.from_config(config)

model.compile(optimizer = optimizer)
# Out:
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! Please ensure your labels are passed as the 'labels' key of the input dict so that they are accessible to the model during the forward pass. To disable this behaviour, please pass a loss argument, or explicitly pass loss=None if you do not want your model to compute a loss.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19364/1546018613.py in <module>
#      15 model = TFAutoModelForCausalLM.from_config(config)
#      16
# ---> 17 model.compile(optimizer = optimizer)
#
# ~\anaconda3\envs\tfgpunew\lib\site-packages\transformers\modeling_tf_utils.py in compile(self, optimizer, loss, metrics, loss_weights, weighted_metrics, run_eagerly, steps_per_execution, **kwargs)
# ...

# %%
model = TFAutoModelForCausalLM.from_pretrained("GPT_50_epochs")
model.compile(optimizer = optimizer)
# Out:
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at GPT_50_epochs.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! Please ensure your labels are passed as the 'labels' key of the input dict so that they are accessible to the model during the forward pass. To disable this behaviour, please pass a loss argument, or explicitly pass loss=None if you do not want your model to compute a loss.

# %%
import numpy as np
class SaveModelPrintMetricsCallback(tf.keras.callbacks.Callback):
    """
    Save best model if vall loss is smaller, used for Transformers package
  """

    def __init__(self, name, metric = "loss", every_n = 10):
        super(SaveModelCallback, self).__init__()
        self.name = name
        self.metric = metric
        self.epoch_saved = 0
        self.every_n = every_n


    def on_train_begin(self, logs=None):
        # Initialize the best as infinity.
        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get(self.metric)
        if np.less(current, self.best):
            self.best = current
            # Record the best weights if current results is better (less).
            self.model.save_pretrained(self.name + " " + str(epoch))
            self.epoch_saved = epoch
        if (self.epoch_saved + self.every_n) < epoch:
            self.model.save_pretrained(self.name + " " + str(epoch))
            self.epoch_saved = epoch

# %% [markdown]
# Now we can train our model. We can also add a callback to sync up our model with the Hub - this allows us to resume training from other machines and even test the model's inference quality midway through training! Make sure to change the `username` if you do. If you don't want to do this, simply remove the callbacks argument in the call to `fit()`.

# %%
model_checkpoint_callback = SaveModelCallback(name = "GPT_50_epochs", metric = "val_loss", every_n = 10)

callbacks = [
    model_checkpoint_callback,
]

# %%
history = model.fit(train_set, validation_data=validation_set, epochs=num_epochs, callbacks = callbacks)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\marty\anaconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 1876/1876 [==============================] - 540s 280ms/step - loss: 3.3281 - val_loss: 3.9148
# Epoch 2/100
# 1876/1876 [==============================] - 527s 281ms/step - loss: 3.2177 - val_loss: 3.9035
# Epoch 3/100
# 1876/1876 [==============================] - 517s 276ms/step - loss: 3.1360 - val_loss: 3.9038
# Epoch 4/100
# 1876/1876 [==============================] - 513s 274ms/step - loss: 3.0605 - val_loss: 3.9164
# Epoch 5/100
# 1876/1876 [==============================] - 513s 273ms/step - loss: 2.9814 - val_loss: 3.9264
# Epoch 6/100
# ...

# %%
from matplotlib import pyplot as plt

l = len(history.history["loss"])
plt.plot(np.arange(l), history.history["loss"], label = "loss")
plt.plot(np.arange(l), history.history["val_loss"], label = "val_loss")
plt.legend()
plt.show()

# %%
model.save_pretrained("GPT_50_epochs 100")

# %% [markdown]
# Once the training is completed, we can evaluate our model and get its loss on the validation set like this:

# %%
eval_loss = model.evaluate(validation_set)
# Out:
# 178/178 [==============================] - 19s 85ms/step - loss: 5.0727

# %%
prompt = "I think"
inputs = tokenizer(prompt, add_special_tokens=False, return_tensors="tf")["input_ids"]

# %%
# Out:
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at GPT_50_epochs.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.

# %%
model = TFAutoModelForCausalLM.from_pretrained("GPT_50_epochs 45")
model.compile()
# Out:
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at GPT_50_epochs 45.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! Please ensure your labels are passed as the 'labels' key of the input dict so that they are accessible to the model during the forward pass. To disable this behaviour, please pass a loss argument, or explicitly pass loss=None if you do not want your model to compute a loss.

# %%
prompt_length = len(tokenizer.decode(inputs[0]))
outputs = model.generate(
    max_length=250, 
    do_sample=True,
    temperature=0.7,
    top_p = 0.8
)
generated = tokenizer.decode(outputs[0])
# Out:
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence

# %%
generated
# Out:
# '<|endoftext|> of open.   We need them.   And they want to do it.   And we\'re going to pay, our military, we\'re going to make a deal with them.   We are going to be in one family, and we\'ll make a level now, and we\'re going to pay their military.   We\'re going to have big, and they\'re going to have it all coming back.   In fact, we\'re going to do all saying, "But we\'re going to be in one family, these letters.   We\'re going to don\'t do this.   I can go back there, the greatest economy.   We are the world.   " I said, "Well, darling?" "I\'m going to pay," because you don\'t have a story.  " And this.   America is over?" And again, we will make a Republican Party Chair, the greatest economy in the greatest economy.   We will rapidly return to full employment, and we are going to love our incredible people, and we are doing great again.   In fact that\'s happening anymore, the Middle East peace in the greatest economy and we are going'

# %%
generated
# Out:
# '<|endoftext|> of it.   And we know what they\'re going to do.   And I\'ll say, "I don\'t know if we did.  " I didn\'t do it, but I\'ll say, "No, we\'ll do it.   We\'ll do it.   We will end it.   We\'ll protect American embassy in line we will defend privacy, free education to keep on the United States to secure border patrol, and we will maintain America will ensure equal justice from the dignity of work and the sanctity of life.   We will maintain American flag.   We will uphold religious liberty, and the right to keep America\'s already built the right to keep and the right to keep and we will strike down terrorists of these incredible wall built the right to keep and the right to keep the true American way of life.   And we will keep on the true American way.   And we will strike down of these people of these people behind me, his constantity of these ridiculous, his next year.   Remember they never let me, his phone call them.   She was his radical left us his next day, "I\'m so
# ...

# %% [markdown]
# The quality of language models is often measured in 'perplexity' rather than cross-entropy. To convert to perplexity, we simply raise e to the power of the cross-entropy loss.

# %% [markdown]
# # N-Gram model

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("gpt2")

# %%
tokens = tokenizer(trump)["input_ids"]
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (391170 > 1024). Running this sequence through the model will result in indexing errors

# %%
import pandas as pd
grams = pd.DataFrame()
n = 2
for i in range(len(tokens) - n):
    i = tokens[i:i+n]
    
grams = [tokens[i:i+n] for i in range(len(tokens) - n)]
grams_mem = pd.DataFrame(grams)

# %%
import numpy as np

def filter_db(db, tokens, iteration = 0):
    n = db.shape[1]
    tokens = tokens[-n:]
    filt = db
    for i in range(n-1 - iteration):
        filt= filt[filt[i+iteration]==tokens[i+iteration]]
    return(filt)

def temperature(dat, temp = 1):
    res = np.exp(dat*temp)
    return res/res.sum()

def top_k(dat, k = 0):
    if k == 0: 
        return dat
    else:
        return dat[:(k)]
    
def top_p(dattemp, p = 1):
    sump = 0
    for i in range(len(dattemp)):
        sump += dattemp.iloc[i]
        if sump > p:
            break

    res = dattemp[:(i+1)]
    res = res/sum(res)
    return res


def sample(tokens, db, temp = 1, k = 0, p = 1):
    n = db.shape[1]
    for i in range(n-1):
        dat = filter_db(db, tokens, i)[n-1].value_counts(normalize = True)
        if len(dat) != 0 :
            break
    dat = temperature(dat,temp)  
    dat = top_k(dat,k)
    dat = top_p(dat,p) 
    return(dat.to_frame().sample(weights = dat.to_frame()[n-1]).index[0])

# %%
ls = tokenizer("you know when you have a hard time")["input_ids"]

# %%
for i in range(50):
    ls.append(sample(ls, grams_mem, temp = 0.7, k = 5, p = 0.6))

# %%
tokenizer.decode(ls)
# Out:
# "you know when you have a hard time., S theyettle were problem saying. how S many military of was a a big very deal,, we I're'm all a. little 8, billion I to said be that in was a a lot great, job and- youB haveaghd aadi very was soon going. on  the They history want of a them very. soon, You they can don do't, have they no don idea't. do  you You.'re 5 all trillion the in United."

# %% [markdown]
# # LSTM model

# %%
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11680/568321786.py in <module>
#       5
#       6 # Add a LSTM layer with 128 internal units.
# ----> 7 model.add(layers.LSTM(128))
#       8
#       9 # Add a Dense layer with 10 units.
#
# ~\anaconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     520     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521     try:
# --> 522       result = method(self, *args, **kwargs)
#     523     finally:
#     524       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
# ...
